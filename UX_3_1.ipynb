# %%
import time
import datetime
import pandas as pd
from datetime import date
import numpy as np
import missingno as msno

# %%
# !pip install --upgrade openpyxl

# %%
columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume']
df = pd.read_excel('UX-dailyhistory.xlsx', header = None, skiprows = 1, names = columns)

# %%
df.head()
# Out:
#         Date     Open     High      Low    Close    Volume
# 0 2022-01-28  1680.13  1746.19  1680.13  1746.19   12930.0
# 1 2022-01-27  1721.92  1737.83  1680.13  1680.13  219915.0
# 2 2022-01-26  1723.80  1734.93  1721.65  1721.92   66560.0
# 3 2022-01-25  1685.07  1723.80  1685.07  1723.80    7027.0
# 4 2022-01-24  1712.41  1712.41  1685.07  1685.07  250780.0

# %%
df.index = df["Date"]
df.index = pd.to_datetime(df.index)
df.drop(['Date', 'Volume'], axis='columns', inplace=True)
df.head()
# Out:
#                Open     High      Low    Close
# Date
# 2022-01-28  1680.13  1746.19  1680.13  1746.19
# 2022-01-27  1721.92  1737.83  1680.13  1680.13
# 2022-01-26  1723.80  1734.93  1721.65  1721.92
# 2022-01-25  1685.07  1723.80  1685.07  1723.80
# 2022-01-24  1712.41  1712.41  1685.07  1685.07

# %%
sum(pd.isnull(df["Open"]))
# Out:
# 301

# %%
sum(pd.isnull(df["High"]))
# Out:
# 301

# %%
sum(pd.isnull(df["Low"]))
# Out:
# 301

# %%
sum(pd.isnull(df["Close"]))
# Out:
# 0

# %%
df[pd.isnull(df["Open"])]
# Out:
#             Open  High  Low    Close
# Date
# 2009-03-25   NaN   NaN  NaN   477.57
# 2009-03-24   NaN   NaN  NaN   472.47
# 2009-03-23   NaN   NaN  NaN   469.05
# 2009-03-20   NaN   NaN  NaN   469.21
# 2009-03-19   NaN   NaN  NaN   463.60
# ...          ...   ...  ...      ...
# 2008-01-14   NaN   NaN  NaN  2907.97
# 2008-01-11   NaN   NaN  NaN  2853.32
# 2008-01-10   NaN   NaN  NaN  2820.05
# 2008-01-09   NaN   NaN  NaN  2781.39
# 2008-01-08   NaN   NaN  NaN  2815.19
#
# [301 rows x 4 columns]

# %%
df[(pd.isnull(df["High"]))]
# Out:
#             Open  High  Low    Close
# Date
# 2009-03-25   NaN   NaN  NaN   477.57
# 2009-03-24   NaN   NaN  NaN   472.47
# 2009-03-23   NaN   NaN  NaN   469.05
# 2009-03-20   NaN   NaN  NaN   469.21
# 2009-03-19   NaN   NaN  NaN   463.60
# ...          ...   ...  ...      ...
# 2008-01-14   NaN   NaN  NaN  2907.97
# 2008-01-11   NaN   NaN  NaN  2853.32
# 2008-01-10   NaN   NaN  NaN  2820.05
# 2008-01-09   NaN   NaN  NaN  2781.39
# 2008-01-08   NaN   NaN  NaN  2815.19
#
# [301 rows x 4 columns]

# %%
df[(pd.isnull(df["Low"]))]
# Out:
#             Open  High  Low    Close
# Date
# 2009-03-25   NaN   NaN  NaN   477.57
# 2009-03-24   NaN   NaN  NaN   472.47
# 2009-03-23   NaN   NaN  NaN   469.05
# 2009-03-20   NaN   NaN  NaN   469.21
# 2009-03-19   NaN   NaN  NaN   463.60
# ...          ...   ...  ...      ...
# 2008-01-14   NaN   NaN  NaN  2907.97
# 2008-01-11   NaN   NaN  NaN  2853.32
# 2008-01-10   NaN   NaN  NaN  2820.05
# 2008-01-09   NaN   NaN  NaN  2781.39
# 2008-01-08   NaN   NaN  NaN  2815.19
#
# [301 rows x 4 columns]

# %%
msno.bar(df, color = (138/225,43/225,225/225))

# %%
msno.matrix(df, color = (178/225,34/225,34/225))

# %%
df = df.dropna()

# %%
msno.matrix(df, color = (178/225,34/225,34/225))
